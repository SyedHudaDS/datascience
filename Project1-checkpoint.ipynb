# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# This goal of this assignment is to understand the logic and methods of exploratory data analysis(EDA).
# The mode of analysis concerned with discovery, exploration, and empirically detecting phenomena in data. EDA had become the default pre-modeling step for every Machine Learning project engagement. Exploratory Data Analysis(EDA) is a way to investigate datasets and preliminary information, insights, or uncover underlying patterns in the data. Instead of making assumptions, data can be processed in a systematic method to gain insights and make informed decisions.
#
# Sweetviz is an open-source Python library that generates beautiful, high-density visualizations to kickstart EDA (Exploratory Data Analysis) with just two lines of code. Output is a fully self-contained HTML application.
#
# The system is built around quickly visualizing target values and comparing datasets. Its goal is to help quick analysis of target characteristics, training vs testing data, and other such data characterization tasks.

# %% [markdown]
# ### Reading Data Frame by using Pandas.

# %% [markdown]
# When we are reading total data using Pandas, there may be wrong values in data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('telco-customer-churn.csv') # read csv into dataframes file using Pandas
n = 3 # the number of data to display
df.head(n)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %% [markdown]
# we can confirm what columns there are in it.

# %%
# Showing Column's names
col_names = df.columns
print(col_names)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# data object struccture
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## clean the data

# %% [markdown]
# Data contain wrong values such as null values. Therefore, we must be thought unuseful data.

# %%
# columns the contains numeric values :  SeniorCitizen,    tenure,    MonthlyCharges,      TotalCharges
df["SeniorCitizen"] = pd.to_numeric(df["SeniorCitizen"],errors='coerce')
ori_shape = df.shape[0]
df = df.dropna()
new_shape = df.shape[0]
print('=======reduced counts : ', ori_shape - new_shape )
df.info()
# Out:
# =======reduced counts :  0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %%
df["tenure"] = pd.to_numeric(df["tenure"],errors='coerce')
ori_shape = df.shape[0]
df = df.dropna()
new_shape = df.shape[0]
print('=======reduced counts : ', ori_shape - new_shape )
df.info()
# Out:
# =======reduced counts :  0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %%
df["MonthlyCharges"] = pd.to_numeric(df["MonthlyCharges"],errors='coerce')
ori_shape = df.shape[0]
df = df.dropna()
new_shape = df.shape[0]
print('=======reduced counts : ', ori_shape - new_shape )
df.info()
# Out:
# =======reduced counts :  0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"],errors='coerce')
ori_shape = df.shape[0]
df = df.dropna()
new_shape = df.shape[0]
print('=======reduced counts : ', ori_shape - new_shape )
df.info()
# Out:
# =======reduced counts :  11
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
# ...

# %% [markdown]
# ###### The database contains 11 null values.

# %% [markdown]
# ## Analyzing the function analyze() of SweetViz And making reports

# %% [markdown]
# ##### Features of sweetviz

# %% [markdown]
# Target analysis, Visualize and compare, Mixed-type associations, Type inference, Summary information

# %%
# Reporting by SweetViz
import sweetviz as sz
report = sz.analyze(df)

# Reporting
report.show_html("sweetviz_total_report.html", open_browser=False, layout='widescreen', scale=None) # generating to "sweetvis_total_report.html"
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_total_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from IPython.display import IFrame
IFrame(src='sweetviz_total_report.html', width = 1000, height=1500)
# Out:
#         <iframe
#             width="1000"
#             height="1500"
#             src="sweetviz_total_report.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# total size of dataframe
df.shape
# Out:
# (7032, 21)

# %%
from sklearn.model_selection import train_test_split
# Spliting total data into train and test datasets for cross-validation(test dataset size : 30%)
train_set, test_set = train_test_split(df, test_size = 0.3)

# %%
# train and test datasets Shape
print('---train dataset shape : ', train_set.shape, '\n')
print('---test dataset shape  : ', test_set.shape)
# Out:
# ---train dataset shape :  (4922, 21)
#
# ---test dataset shape  :  (2110, 21)

# %% [markdown]
# ##### Comparing  train dataset and test dataset by using the funciton compare() of Sweetviz

# %%
# Comparing train and test datasets by using compare function of Sweetviz
compare = sz.compare([train_set, "train dataset"], [test_set, "test dataset"])
#show report
compare.show_html("train_test_report.html", open_browser=False, layout='widescreen', scale=None)
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report train_test_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from IPython.display import IFrame
IFrame(src='train_test_report.html', width = 1000, height=1500)
# Out:
#         <iframe
#             width="1000"
#             height="1500"
#             src="train_test_report.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4),dpi=500)
sns.distplot(df['tenure'])
plt.title("Density VS Tenure");
# Out:
# C:\Users\Beny\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import skew

skew(df['tenure'])
# Out:
# 0.23768011839839964

# %%
sns.boxplot(x='tenure', y='Churn', data = df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Churn'>

# %%
import seaborn as sns

sns.set(rc={'figure.figsize': (14, 8)})
sns.countplot(df['SeniorCitizen'])
# Out:
# C:\Users\Beny\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (14, 8)})
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=2)
# Out:
# <AxesSubplot:>

# %%
train_set_x, train_set_y, test_set_x, test_set_y  = train_set.iloc[:, 0:20], train_set.iloc[:, 20], test_set.iloc[:, 0:20], test_set.iloc[:, 20]

# %%
train_set_x
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 417   5249-QYHEX  Female              0     Yes        Yes      40
# 4520  3506-LCJDC    Male              0     Yes        Yes       1
# 4342  5792-JALQC  Female              1      No         No      52
# 6392  3999-WRNGR  Female              0     Yes        Yes      60
# 2021  0181-RITDD    Male              0     Yes        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 254   3675-YDUPJ    Male              0      No         No      10
# 4507  7797-EJMDP  Female              0      No         No       8
# 1289  9968-FFVVH    Male              0      No         No      63
# 1233  1299-AURJA  Female              0     Yes        Yes      70
# 5276  2725-IWWBA    Male              0     Yes        Yes      46
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 417           Yes               Yes              No  No internet service
# ...

# %%
train_set_y
# Out:
# 417      No
# 4520    Yes
# 4342     No
# 6392     No
# 2021     No
#        ...
# 254      No
# 4507     No
# 1289     No
# 1233     No
# 5276     No
# Name: Churn, Length: 4922, dtype: object

# %%
test_set_x
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 412   5233-AOZUF  Female              0     Yes         No      29
# 225   6778-JFCMK    Male              0      No         No      24
# 3128  2739-CCZMB    Male              0      No        Yes       5
# 3028  8740-XLHDR    Male              0      No         No       5
# 1778  6181-AXXYF    Male              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 2416  8982-NHAVY    Male              0      No         No      27
# 4207  8706-HRADD    Male              0      No         No      21
# 3182  6568-POCUI  Female              0     Yes         No      45
# 736   6647-ZEDXT  Female              0      No         No      30
# 3509  8710-YGLWG    Male              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 412           Yes               Yes     Fiber optic                   No
# ...

# %%
test_set_y
# Out:
# 412      No
# 225      No
# 3128     No
# 3028    Yes
# 1778     No
#        ...
# 2416     No
# 4207     No
# 3182     No
# 736      No
# 3509     No
# Name: Churn, Length: 2110, dtype: object
